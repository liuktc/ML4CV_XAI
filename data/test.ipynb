# %%
# %load_ext autoreload

# %autoreload 2


from imagewoof import Imagewoof

dataset = Imagewoof(".", split="train", size="320px", download=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# imagewoof2-320
# Using downloaded and verified file: .\imagewoof2-320.tgz
# Extracting .\imagewoof2-320.tgz to .

# %%
import matplotlib.pyplot as plt
for image,label in dataset:
    plt.imshow(image)
    print(image, label)
    break
# Out:
# <PIL.Image.Image image mode=RGB size=320x333 at 0x18F0A12E3E0> 0
