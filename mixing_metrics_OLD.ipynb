# %%
# !rm -rf ./ML4CV_XAI
# !git clone https://github.com/liuktc/ML4CV_XAI.git
# !pip install captum grad_cam Craft-xai torcheval
# %load_ext autoreload

# %autoreload 2

import sys
sys.path.append('/kaggle/working/ML4CV_XAI')

# %%
# %load_ext autoreload

# %autoreload 2

import numpy as np
import torch
from torch.utils.data import DataLoader

from utils import _DeepLiftShap, _GradCAMPlusPlus, SimpleUpsampling,ERFUpsamplingFast, min_max_normalize
from data import PascalVOC2007
from results.results_metrics import ResultMetrics
from models import vgg11_PascalVOC, vgg_preprocess

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
torch.manual_seed(123)
np.random.seed(123)

# %%
model = vgg11_PascalVOC()
model.to(device)
# Load the pretrained weights
model.load_state_dict(torch.load('VGG11_PascalVOC.pt', map_location=device))
model.eval()

preprocess = vgg_preprocess

# %%
test_data = PascalVOC2007("test", transform=preprocess)
train_data = PascalVOC2007("trainval", transform=preprocess)
# Out:
# Using downloaded and verified file: data\VOCtest_06-Nov-2007.tar
# Extracting data\VOCtest_06-Nov-2007.tar to data
# Using downloaded and verified file: data\VOCtrainval_06-Nov-2007.tar
# Extracting data\VOCtrainval_06-Nov-2007.tar to data

# %%
import torch.utils
from torch.utils.data import Subset

BATCH_SIZE_TEST = 1
NUM_TEST = 128

BATCH_SIZE_TRAIN = 2
NUM_TRAIN = 16

dl_test = DataLoader(Subset(test_data, torch.randperm(len(test_data))[:NUM_TEST]), batch_size=BATCH_SIZE_TEST, shuffle=False)
dl_train = DataLoader(Subset(train_data, torch.randperm(len(train_data))[:NUM_TRAIN]), batch_size=BATCH_SIZE_TRAIN, shuffle=True)

# %%
baseline_dist_16 = torch.cat([images for images, _ in dl_train], dim=0).to(device)
baseline_dist_8 = baseline_dist_16[:8].clone()
baseline_dist_4 = baseline_dist_16[:4].clone()

# %%
LAYERS = [20,15,10,5]

# %%
from metrics import RoadCombined
from utils import MultiplierMix
from tqdm.auto import tqdm

results = ResultMetrics("./results_mixed.csv")

for index, (images, labels) in enumerate(tqdm(dl_test)):
    images = images.to(device)
    labels = labels.to(device).reshape(-1)

    # Make sure that LAYERS is sorted in descending order
    LAYERS.sort(reverse=True)
    # for attribution_method in [_DeepLiftShap(baseline_dist_8, name="DeepLiftShap8"), _GradCAMPlusPlus]:
    for attribution_method in [_DeepLiftShap(baseline_dist_8, name="DeepLiftShap8")]:
        # for upsample_method in [ERFUpsamplingFast(), SimpleUpsampling((224,224))]:
        for upsample_method in [ERFUpsamplingFast()]:
            attributions_per_layer = []
            for layer_index in LAYERS:
                layer = model.features[layer_index]
                attribution_map = attribution_method.attribute(input_tensor=images,
                                                                model=model,
                                                                layer=layer,
                                                                target=labels
                                                                )
                

                # upsample_method = SimpleUpsampling((224,224))
                attribution_map = upsample_method(attribution=attribution_map,
                                                  image=images,
                                                  device=device,
                                                  model=model,
                                                  layer=layer)

                if (torch.abs(
                    attribution_map.amax(dim=(2, 3), keepdim=True)
                    - attribution_map.amin(dim=(2, 3), keepdim=True)
                )
                < 1e-6  ).any():
                    print("A saliency map is constant, skipping batch")
                    del images, labels, attribution_map
                    torch.cuda.empty_cache()
                    continue

                attribution_map = min_max_normalize(attribution_map)
                attributions_per_layer.append(attribution_map)

                # Mix the attribution maps
                mix = MultiplierMix(layers_to_combine="all")
                mixed_attribution_map = mix(attributions_per_layer)

                for metric in [RoadCombined()]:
                    metric_result_normal = metric(model=model,
                            test_images=images,
                            saliency_maps=attribution_map,
                            class_idx=labels,
                            attribution_method=attribution_method,
                            device=device,
                            layer=layer)
                    
                    results.add_result(model="VGG11",
                                       attribution_method=attribution_method.name,
                                       dataset="PascalVOC",
                                       layer=f"features.{layer_index}",
                                       metric=metric.name,
                                       upscale_method=upsample_method.name,
                                       mixing_method= "None",
                                       value=metric_result_normal,
                                       image_index=index)

                    metric_result_mixed = metric(model=model,
                            test_images=images,
                            saliency_maps=mixed_attribution_map,
                            class_idx=labels,
                            attribution_method=attribution_method,
                            device=device,
                            layer=layer)
                    
                    
                    results.add_result(model="VGG11",
                                       attribution_method=attribution_method.name,
                                       dataset="PascalVOC",
                                       layer=f"features.{layer_index}",
                                       metric=metric.name,
                                       upscale_method=upsample_method.name,
                                       mixing_method= mix.name,
                                       value=metric_result_mixed,
                                       image_index=index)
                break
            break
        break
    break
# Out:
# Results loaded from ./results_mixed.csv.
#   0%|          | 0/128 [00:00<?, ?it/s]
# c:\Users\Luca\AppData\Local\Programs\Python\Python310\lib\site-packages\captum\attr\_core\deep_lift.py:304: UserWarning: Setting forward, backward hooks and attributes on non-linear
#                activations. The hooks and attributes will be removed
#             after the attribution is finished
#   warnings.warn(
#          70180 function calls (65328 primitive calls) in 5.000 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        16    1.624    0.101    1.624    0.101 {built-in method scipy.sparse.linalg._dsolve._superlu.gssv}
#       280    1.311    0.005    1.311    0.005 {built-in method torch.conv2d}
#        16    0.632    0.040    0.634    0.040 _lil.py:23(__init__)
#       105    0.347    0.003    0.347    0.003 {built-in method torch._C._nn.linear}
#       144    0.336    0.002    0.341    0.002 _lil.py:255(_set_arrayXarray)
#       175    0.163    0.001    0.163    0.001 {built-in method torch.max_pool2d}
#        16    0.101    0.006    2.950    0.184 perturbation_confidence.py:60(__call__)
#         2    0.092    0.046    0.093    0.046 {method 'run_backward' of 'torch._C._EngineBase' objects}
#        16    0.057    0.004    1.101    0.069 road.py:75(setup_sparse_system)
#        16    0.057    0.004    0.060    0.004 _lil.py:402(tocsr)
#       350    0.035    0.000    0.035    0.000 {built-in method torch.relu_}
#       128    0.033    0.000    0.033    0.000 road.py:62(add_offset_to_indices)
#        16    0.015    0.001    0.015    0.001 {built-in method scipy.sparse._sparsetools.csr_tocsc}
#         4    0.012    0.003    0.012    0.003 {built-in method scipy.ndimage._nd_image.correlate1d}
#         6    0.008    0.001    0.008    0.001 {built-in method io.open}
#        16    0.006    0.000    0.006    0.000 {built-in method torch.randn_like}
#        16    0.006    0.000    2.840    0.177 road.py:118(__call__)
#       268    0.006    0.000    0.006    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        16    0.006    0.000    0.087    0.005 _base.py:1082(tocsc)
#       401    0.005    0.000    0.005    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#   1120/40    0.005    0.000    1.983    0.050 module.py:1534(_call_impl)
#        70    0.005    0.000    1.886    0.027 container.py:215(forward)
#        16    0.004    0.000    0.004    0.000 {built-in method torch.tensor}
#        17    0.004    0.000    0.004    0.000 {method 'partition' of 'numpy.ndarray' objects}
#      1157    0.004    0.000    0.004    0.000 {built-in method torch._C._get_tracing_state}
#       144    0.004    0.000    0.010    0.000 _index.py:212(_validate_indices)
#   1120/40    0.004    0.000    1.983    0.050 module.py:1528(_wrapped_call_impl)
# 1387/1384    0.003    0.000    0.003    0.000 {built-in method numpy.asarray}
#       280    0.003    0.000    1.316    0.005 conv.py:459(forward)
#       450    0.002    0.000    0.002    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#       144    0.002    0.000    0.358    0.002 _index.py:124(__setitem__)
#        16    0.002    0.000    0.002    0.000 {method 'nonzero' of 'torch._C.TensorBase' objects}
#        16    0.002    0.000    0.002    0.000 {built-in method scipy.sparse._sparsetools.csr_has_canonical_format}
#       259    0.002    0.000    0.002    0.000 {built-in method numpy.empty}
#        16    0.002    0.000    4.432    0.277 perturbation_confidence.py:13(__call__)
#        30    0.002    0.000    0.002    0.000 {method 'acquire' of '_thread.lock' objects}
#        32    0.002    0.000    0.002    0.000 {built-in method torch._C._nn.adaptive_avg_pool2d}
#        16    0.002    0.000    0.002    0.000 {method 'transpose' of 'torch._C.TensorBase' objects}
#       128    0.002    0.000    0.002    0.000 stride_tricks.py:340(_broadcast_to)
#       416    0.002    0.000    0.005    0.000 fromnumeric.py:40(_wrapit)
#         1    0.002    0.002    0.115    0.115 util.py:265(calculate_erf_on_attribution)
#        22    0.002    0.000    0.002    0.000 {built-in method torch.cat}
#       416    0.002    0.000    0.019    0.000 numeric.py:561(argwhere)
#        20    0.002    0.000    0.002    0.000 socket.py:621(send)
#       132    0.001    0.000    0.001    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       288    0.001    0.000    0.005    0.000 _index.py:10(_broadcast_arrays)
#       940    0.001    0.000    0.001    0.000 module.py:1696(__getattr__)
#       848    0.001    0.000    0.017    0.000 fromnumeric.py:53(_wrapfunc)
#       280    0.001    0.000    1.312    0.005 conv.py:451(_conv_forward)
#       350    0.001    0.000    0.038    0.000 activation.py:102(forward)
# 5753/5706    0.001    0.000    0.002    0.000 {built-in method builtins.isinstance}
#        16    0.001    0.000    0.021    0.001 _csr.py:63(tocsc)
#       288    0.001    0.000    0.001    0.000 stride_tricks.py:416(_broadcast_shape)
#        33    0.001    0.000    0.001    0.000 {built-in method numpy.zeros}
#        24    0.001    0.000    0.001    0.000 {method 'clone' of 'torch._C.TensorBase' objects}
#        70    0.001    0.000    0.002    0.000 functional.py:1279(dropout)
#       350    0.001    0.000    0.036    0.000 functional.py:1489(relu)
#        48    0.001    0.000    0.001    0.000 _sputils.py:264(get_index_dtype)
#        60    0.001    0.000    0.001    0.000 {built-in method numpy.arange}
#        32    0.001    0.000    1.472    0.046 vgg.py:65(forward)
#         2    0.001    0.000    0.001    0.000 {method 'decode' of 'ImagingDecoder' objects}
#       115    0.001    0.000    0.001    0.000 {method 'numpy' of 'torch._C.TensorBase' objects}
#       175    0.001    0.000    0.165    0.001 pooling.py:163(forward)
# 2793/2342    0.001    0.000    0.005    0.000 {built-in method builtins.getattr}
#       288    0.001    0.000    0.003    0.000 stride_tricks.py:480(broadcast_arrays)
#         1    0.001    0.001    0.001    0.001 {method 'read_low_memory' of 'pandas._libs.parsers.TextReader' objects}
#       144    0.001    0.000    0.004    0.000 _lil.py:437(_prepare_index_for_memoryview)
#        17    0.001    0.000    0.007    0.000 function_base.py:4765(_quantile)
#       432    0.001    0.000    0.001    0.000 shape_base.py:81(atleast_2d)
#       175    0.001    0.000    0.164    0.001 _jit_internal.py:487(fn)
#       144    0.001    0.000    0.359    0.002 _lil.py:267(__setitem__)
#       114    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       105    0.001    0.000    0.348    0.003 linear.py:115(forward)
#         4    0.001    0.000    0.001    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#       608    0.001    0.000    0.001    0.000 _sputils.py:350(isintlike)
#        35    0.001    0.000    0.001    0.000 {method 'unbind' of 'torch._C.TensorBase' objects}
#     48/16    0.001    0.000    0.088    0.006 _compressed.py:29(__init__)
#        32    0.001    0.000    0.001    0.000 {built-in method torch.softmax}
#        32    0.001    0.000    0.001    0.000 {built-in method torch.flatten}
#        16    0.001    0.000    0.001    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
# 4260/4103    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#         7    0.001    0.000    0.001    0.000 {method 'amin' of 'torch._C.TensorBase' objects}
#        32    0.001    0.000    0.001    0.000 model_targets.py:20(__call__)
#        32    0.001    0.000    0.001    0.000 utils.py:33(_list_with_default)
#        16    0.001    0.000    0.001    0.000 numeric.py:136(ones)
#        70    0.001    0.000    0.001    0.000 {built-in method torch.dropout}
#        17    0.000    0.000    0.010    0.001 function_base.py:3992(percentile)
#        17    0.000    0.000    0.000    0.000 function_base.py:4641(_lerp)
#  1026/288    0.000    0.000    0.001    0.000 module.py:2369(named_modules)
#         1    0.000    0.000    0.004    0.004 pascalvoc.py:77(__getitem__)
#       175    0.000    0.000    0.163    0.001 functional.py:774(_max_pool2d)
#       112    0.000    0.000    0.000    0.000 getlimits.py:685(__init__)
#       820    0.000    0.000    0.001    0.000 {built-in method numpy.array}
#      1024    0.000    0.000    0.000    0.000 fromnumeric.py:3176(ndim)
#         8    0.000    0.000    0.000    0.000 {built-in method torch.rsub}
#       682    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function_unary}
#  1254/635    0.000    0.000    0.004    0.000 traitlets.py:708(__get__)
#         1    0.000    0.000    0.130    0.130 attributions.py:117(forward)
#        18    0.000    0.000    0.000    0.000 {method 'unsqueeze' of 'torch._C.TensorBase' objects}
#       901    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        16    0.000    0.000    1.627    0.102 linsolve.py:133(spsolve)
#       288    0.000    0.000    0.000    0.000 _index.py:423(_compatible_boolean_index)
#        17    0.000    0.000    0.001    0.000 function_base.py:4730(_get_indexes)
#        24    0.000    0.000    0.001    0.000 traitlets.py:1921(traits)
#       288    0.000    0.000    0.000    0.000 shape_base.py:23(atleast_1d)
#         4    0.000    0.000    0.000    0.000 {method 'amax' of 'torch._C.TensorBase' objects}
#       416    0.000    0.000    0.009    0.000 fromnumeric.py:1881(nonzero)
#        17    0.000    0.000    0.001    0.000 function_base.py:4565(_quantile_is_valid)
#        49    0.000    0.000    0.000    0.000 {built-in method torch.from_numpy}
#        48    0.000    0.000    0.001    0.000 _compressed.py:165(check_format)
#        37    0.000    0.000    0.000    0.000 {method 'reshape' of 'torch._C.TensorBase' objects}
#       864    0.000    0.000    0.000    0.000 stride_tricks.py:542(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {built-in method nt.stat}
#        48    0.000    0.000    0.001    0.000 _sputils.py:429(check_shape)
#       288    0.000    0.000    0.001    0.000 stride_tricks.py:538(<listcomp>)
#         2    0.000    0.000    0.001    0.000 deep_lift.py:867(nonlinear)
#   968/564    0.000    0.000    0.004    0.000 traitlets.py:624(get)
#         1    0.000    0.000    4.988    4.988 2003337490.py:1(<module>)
#        17    0.000    0.000    0.000    0.000 arraysetops.py:323(_unique1d)
#        56    0.000    0.000    0.000    0.000 encoder.py:204(iterencode)
#        38    0.000    0.000    0.000    0.000 {method 'to' of 'torch._C.TensorBase' objects}
#        16    0.000    0.000    0.000    0.000 _matrix.py:23(_csr_container)
#   338/337    0.000    0.000    0.001    0.000 {built-in method builtins.all}
#      2041    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       332    0.000    0.000    0.001    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 {method 'contiguous' of 'torch._C.TensorBase' objects}
#        48    0.000    0.000    0.001    0.000 _compressed.py:1284(prune)
#       177    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        67    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}
#       283    0.000    0.000    0.000    0.000 traitlets.py:1952(trait_metadata)
#        58    0.000    0.000    0.001    0.000 construction.py:518(sanitize_array)
#        51    0.000    0.000    0.001    0.000 fromnumeric.py:71(_wrapreduction)
#         4    0.000    0.000    4.433    1.108 perturbation_confidence.py:100(__call__)
#       592    0.000    0.000    0.000    0.000 _base.py:70(ndim)
#         3    0.000    0.000    0.001    0.000 util.py:205(min_max_normalize)
#        35    0.000    0.000    0.001    0.000 _tensor.py:1037(__iter__)
#       528    0.000    0.000    0.000    0.000 _base.py:1401(issparse)
#        32    0.000    0.000    0.000    0.000 {method 't' of 'torch._C.TensorBase' objects}
#         5    0.000    0.000    0.000    0.000 {method 'sum' of 'torch._C.TensorBase' objects}
#       930    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#       416    0.000    0.000    0.008    0.000 fromnumeric.py:588(transpose)
#        64    0.000    0.000    0.000    0.000 _base.py:114(__init__)
#        32    0.000    0.000    0.003    0.000 functional.py:1248(adaptive_avg_pool2d)
#       416    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#        67    0.000    0.000    0.000    0.000 grad_mode.py:183(__init__)
#        70    0.000    0.000    0.000    0.000 container.py:207(__iter__)
#       288    0.000    0.000    0.000    0.000 _lil.py:164(_asindices)
#        48    0.000    0.000    0.002    0.000 _base.py:1369(_get_index_dtype)
#        70    0.000    0.000    0.002    0.000 dropout.py:58(forward)
#        33    0.000    0.000    0.000    0.000 grad_mode.py:74(__init__)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#      1024    0.000    0.000    0.000    0.000 fromnumeric.py:3172(_ndim_dispatcher)
#        68    0.000    0.000    0.000    0.000 {method 'cpu' of 'torch._C.TensorBase' objects}
#        19    0.000    0.000    0.000    0.000 {method 'flatten' of 'torch._C.TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'resize' of 'ImagingCore' objects}
#        15    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#      13/6    0.000    0.000    0.004    0.001 widget.py:589(get_state)
#        16    0.000    0.000    0.000    0.000 _matrix.py:18(_csc_container)
#        33    0.000    0.000    0.000    0.000 _contextlib.py:149(__new__)
#         2    0.000    0.000    0.000    0.000 deep_lift.py:1032(_compute_diffs)
#        80    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:404(parent)
#        16    0.000    0.000    0.000    0.000 _sputils.py:112(getdtype)
#        70    0.000    0.000    0.000    0.000 _VF.py:26(__getattr__)
#         4    0.000    0.000    0.000    0.000 _filters.py:226(_gaussian_kernel1d)
#        34    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#        68    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#         6    0.000    0.000    0.000    0.000 _methods.py:101(_mean)
#       256    0.000    0.000    0.000    0.000 _compressed.py:117(_getnnz)
#        33    0.000    0.000    0.000    0.000 grad_mode.py:83(__exit__)
#        50    0.000    0.000    0.000    0.000 {method 'size' of 'torch._C.TensorBase' objects}
#       128    0.000    0.000    0.002    0.000 stride_tricks.py:367(broadcast_to)
#        14    0.000    0.000    0.001    0.000 session.py:688(serialize)
#       288    0.000    0.000    0.000    0.000 _index.py:298(<genexpr>)
#         2    0.000    0.000    0.000    0.000 {built-in method torch.where}
#         1    0.000    0.000    0.000    0.000 {built-in method torch.max}
#        16    0.000    0.000    0.000    0.000 {method 'reshape_as' of 'torch._C.TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 deep_lift.py:333(<genexpr>)
#       987    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        41    0.000    0.000    0.000    0.000 {method 'read' of '_io.BufferedReader' objects}
#         8    0.000    0.000    1.388    0.174 perturbation_confidence.py:78(__call__)
#        17    0.000    0.000    0.008    0.000 function_base.py:3763(_ureduce)
#        16    0.000    0.000    0.000    0.000 flags.py:53(__init__)
#       416    0.000    0.000    0.000    0.000 numeric.py:557(_argwhere_dispatcher)
#   264/263    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        16    0.000    0.000    0.001    0.000 perturbation_confidence.py:23(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'repeat_interleave' of 'torch._C.TensorBase' objects}
#        14    0.000    0.000    0.002    0.000 session.py:752(send)
#       131    0.000    0.000    0.000    0.000 function_base.py:348(iterable)
#       432    0.000    0.000    0.000    0.000 _index.py:297(<genexpr>)
#        56    0.000    0.000    0.000    0.000 numerictypes.py:357(issubdtype)
#        11    0.000    0.000    0.000    0.000 dir2.py:54(get_real_method)
#        67    0.000    0.000    0.000    0.000 numeric.py:274(full)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:60(__init__)
#        69    0.000    0.000    0.000    0.000 {built-in method torch._C._set_grad_enabled}
#        79    0.000    0.000    0.000    0.000 traitlets.py:1546(_notify_observers)
#         2    0.000    0.000    0.000    0.000 {built-in method torch.abs}
#         4    0.000    0.000    0.000    0.000 {built-in method torch.stack}
#        17    0.000    0.000    0.000    0.000 function_base.py:110(<lambda>)
#       256    0.000    0.000    0.000    0.000 _base.py:341(nnz)
#         1    0.000    0.000    0.014    0.014 util.py:294(post_process_erf)
#         1    0.000    0.000    0.000    0.000 {built-in method PIL._imaging.new}
#        16    0.000    0.000    0.001    0.000 perturbation_confidence.py:39(<listcomp>)
#         1    0.000    0.000    0.000    0.000 ElementTree.py:1520(__init__)
#        11    0.000    0.000    0.000    0.000 inspect.py:3050(_bind)
#      86/1    0.000    0.000    0.000    0.000 voc.py:208(parse_voc_xml)
#       112    0.000    0.000    0.000    0.000 numerictypes.py:283(issubclass_)
#         9    0.000    0.000    0.001    0.000 base.py:477(__new__)
#       144    0.000    0.000    0.000    0.000 _sputils.py:457(<genexpr>)
#       384    0.000    0.000    0.000    0.000 _matrix.py:65(get_shape)
#       289    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#     18/13    0.000    0.000    0.000    0.000 widget.py:87(_separate_buffers)
#       7/4    0.000    0.000    0.001    0.000 inspect.py:2375(_signature_from_callable)
#        17    0.000    0.000    0.000    0.000 function_base.py:4619(_get_gamma)
#        32    0.000    0.000    0.001    0.000 _tensor.py:1083(__array__)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'ImagingCore' objects}
#        34    0.000    0.000    0.001    0.000 fromnumeric.py:2421(all)
#       128    0.000    0.000    0.000    0.000 stride_tricks.py:25(_maybe_view_as_subclass)
#        61    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        33    0.000    0.000    0.000    0.000 grad_mode.py:79(__enter__)
#         1    0.000    0.000    0.000    0.000 {method 'div' of 'torch._C.TensorBase' objects}
#        12    0.000    0.000    0.000    0.000 concat.py:52(concat_compat)
#         4    0.000    0.000    0.003    0.001 frame.py:668(__init__)
#         2    0.000    0.000    0.000    0.000 std.py:464(format_meter)
#     63/21    0.000    0.000    0.004    0.000 traitlets.py:1895(trait_defaults)
#         1    0.000    0.000    0.000    0.000 {method 'div_' of 'torch._C.TensorBase' objects}
#        16    0.000    0.000    0.002    0.000 _compressed.py:1199(has_canonical_format)
#         4    0.000    0.000    0.000    0.000 managers.py:2137(_form_blocks)
#        48    0.000    0.000    0.000    0.000 _sputils.py:372(isshape)
#        12    0.000    0.000    0.000    0.000 formatters.py:396(lookup_by_type)
#        32    0.000    0.000    0.000    0.000 module.py:1711(__setattr__)
#         3    0.000    0.000    0.000    0.000 {method 'get_slice' of 'pandas._libs.internals.BlockManager' objects}
#         2    0.000    0.000    0.000    0.000 {method 'Parse' of 'pyexpat.xmlparser' objects}
#        96    0.000    0.000    0.000    0.000 _util.py:229(_prune_array)
#         2    0.000    0.000    0.001    0.000 concat.py:94(concatenate_managers)
#         1    0.000    0.000    0.064    0.064 deep_lift.py:142(attribute)
#         1    0.000    0.000    0.000    0.000 {built-in method torch.mean}
#         3    0.000    0.000    0.000    0.000 common.py:627(_verify_select_column)
#         4    0.000    0.000    0.009    0.002 common.py:652(get_handle)
#         2    0.000    0.000    0.001    0.000 util.py:70(cut_model_to_layer)
#      1085    0.000    0.000    0.000    0.000 typing.py:1737(cast)
#       288    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#        28    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.isnaobj}
#        48    0.000    0.000    0.000    0.000 _data.py:21(__init__)
#       233    0.000    0.000    0.000    0.000 generic.py:37(_check)
#         6    0.000    0.000    0.000    0.000 concat.py:572(_is_uniform_join_units)
#        42    0.000    0.000    0.000    0.000 cast.py:1147(maybe_infer_to_datetimelike)
#        63    0.000    0.000    0.000    0.000 traitlets.py:1883(_get_trait_default_generator)
#         1    0.000    0.000    0.003    0.003 display_functions.py:45(publish_display_data)
#        14    0.000    0.000    0.000    0.000 missing.py:261(_isna_array)
#       233    0.000    0.000    0.000    0.000 generic.py:42(_instancecheck)
#         4    0.000    0.000    0.000    0.000 inspect.py:2280(_signature_from_function)
#        48    0.000    0.000    0.000    0.000 getlimits.py:696(min)
#        13    0.000    0.000    0.002    0.000 comm.py:24(publish_msg)
#        64    0.000    0.000    0.000    0.000 getlimits.py:709(max)
#        56    0.000    0.000    0.001    0.000 __init__.py:183(dumps)
#        32    0.000    0.000    0.003    0.000 pooling.py:1266(forward)
#         3    0.000    0.000    0.000    0.000 {pandas._libs.writers.write_csv_rows}
#        17    0.000    0.000    0.008    0.000 function_base.py:4697(_quantile_ureduce_func)
#        20    0.000    0.000    0.000    0.000 common.py:123(<lambda>)
#        14    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#       6/4    0.000    0.000    0.001    0.000 series.py:371(__init__)
#        56    0.000    0.000    0.001    0.000 encoder.py:182(encode)
#       120    0.000    0.000    0.000    0.000 formatters.py:552(_in_deferred_types)
#         1    0.000    0.000    0.000    0.000 {method 'repeat' of 'torch._C.TensorBase' objects}
#        25    0.000    0.000    0.000    0.000 missing.py:184(_isna)
#         2    0.000    0.000    0.002    0.001 construction.py:423(dict_to_mgr)
#        16    0.000    0.000    0.087    0.005 _base.py:428(asformat)
#        20    0.000    0.000    0.002    0.000 iostream.py:259(schedule)
#        17    0.000    0.000    0.000    0.000 {method 'sort' of 'numpy.ndarray' objects}
#     90/84    0.000    0.000    0.000    0.000 traitlets.py:750(_validate)
#        50    0.000    0.000    0.000    0.000 module.py:573(add_module)
#        80    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 blocks.py:2499(to_native_types)
#        13    0.000    0.000    0.001    0.000 managers.py:308(apply)
#         2    0.000    0.000    0.000    0.000 std.py:1446(format_dict)
#         3    0.000    0.000    0.004    0.001 generic.py:3720(to_csv)
#        17    0.000    0.000    0.000    0.000 arraysetops.py:138(unique)
#         4    0.000    0.000    0.012    0.003 _filters.py:125(correlate1d)
#         4    0.000    0.000    0.001    0.000 construction.py:596(_homogenize)
#        48    0.000    0.000    0.000    0.000 _sputils.py:543(is_pydata_spmatrix)
#        32    0.000    0.000    0.000    0.000 utils.py:41(<listcomp>)
#       256    0.000    0.000    0.000    0.000 stride_tricks.py:345(<genexpr>)
#         1    0.000    0.000    0.025    0.025 attribution.py:160(compute_convergence_delta)
#        16    0.000    0.000    0.000    0.000 base.py:648(_simple_new)
#       416    0.000    0.000    0.000    0.000 fromnumeric.py:1877(_nonzero_dispatcher)
#       100    0.000    0.000    0.000    0.000 {built-in method torch.is_grad_enabled}
#       416    0.000    0.000    0.000    0.000 fromnumeric.py:584(_transpose_dispatcher)
#        14    0.000    0.000    0.000    0.000 hooks.py:23(__init__)
#        16    0.000    0.000    0.000    0.000 generic.py:274(__init__)
#         8    0.000    0.000    0.000    0.000 road.py:150(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:60(_make_grads)
#        16    0.000    0.000    0.001    0.000 widget.py:691(notify_change)
#       288    0.000    0.000    0.000    0.000 stride_tricks.py:476(_broadcast_arrays_dispatcher)
#        17    0.000    0.000    0.008    0.000 function_base.py:4547(_quantile_unchecked)
#       288    0.000    0.000    0.000    0.000 shape_base.py:19(_atleast_1d_dispatcher)
#         6    0.000    0.000    0.000    0.000 _methods.py:67(_count_reduce_items)
#         2    0.000    0.000    0.000    0.000 {built-in method torch.empty}
#       432    0.000    0.000    0.000    0.000 shape_base.py:77(_atleast_2d_dispatcher)
#         5    0.000    0.000    0.000    0.000 module.py:428(__init__)
#         2    0.000    0.000    0.006    0.003 results_metrics.py:38(add_result)
#        37    0.000    0.000    0.000    0.000 {method 'dim' of 'torch._C.TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sub_' of 'torch._C.TensorBase' objects}
#         4    0.000    0.000    0.000    0.000 _tensor.py:529(register_hook)
#         4    0.000    0.000    0.000    0.000 {method 'chunk' of 'torch._C.TensorBase' objects}
#         2    0.000    0.000    4.433    2.217 road.py:17(__call__)
#         1    0.000    0.000    0.000    0.000 _functional_tensor.py:903(normalize)
#        11    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#        16    0.000    0.000    0.000    0.000 _tensor.py:1093(__array_wrap__)
#         8    0.000    0.000    0.000    0.000 {method 'detach' of 'torch._C.TensorBase' objects}
#         8    0.000    0.000    0.000    0.000 road.py:144(__init__)
#         6    0.000    0.000    0.000    0.000 base.py:1438(_format_native_types)
#         3    0.000    0.000    0.001    0.000 csvs.py:311(_save_chunk)
#       538    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        67    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.037    0.037 gradient.py:88(compute_gradients)
#        70    0.000    0.000    0.000    0.000 _methods.py:55(_any)
#         1    0.000    0.000    0.001    0.001 functional.py:127(to_tensor)
#      11/4    0.000    0.000    0.005    0.001 widget.py:522(open)
#        10    0.000    0.000    0.000    0.000 {method 'item' of 'torch._C.TensorBase' objects}
#        51    0.000    0.000    0.000    0.000 fromnumeric.py:72(<dictcomp>)
#         4    0.000    0.000    0.013    0.003 _filters.py:257(gaussian_filter1d)
#        56    0.000    0.000    0.001    0.000 session.py:92(json_packer)
#         7    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#         4    0.000    0.000    0.000    0.000 common.py:539(_select_targets)
#        30    0.000    0.000    0.001    0.000 base.py:7512(ensure_index)
#         8    0.000    0.000    0.000    0.000 generic.py:6147(__finalize__)
#        16    0.000    0.000    0.001    0.000 fromnumeric.py:2512(cumsum)
#       122    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#        20    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#        96    0.000    0.000    0.000    0.000 _base.py:74(_shape_as_2d)
#        11    0.000    0.000    0.000    0.000 uuid.py:138(__init__)
#        11    0.000    0.000    0.002    0.000 base_comm.py:24(__init__)
#         1    0.000    0.000    0.064    0.064 deep_lift.py:612(attribute)
#         9    0.000    0.000    0.000    0.000 blocks.py:1127(setitem)
#        98    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FF98489C920}
#         2    0.000    0.000    0.000    0.000 {method 'any' of 'torch._C.TensorBase' objects}
#         6    0.000    0.000    0.000    0.000 common.py:1148(is_float_dtype)
#        32    0.000    0.000    0.000    0.000 parameter.py:8(__instancecheck__)
#         7    0.000    0.000    0.000    0.000 base.py:5518(equals)
#         1    0.000    0.000    0.000    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#       128    0.000    0.000    0.000    0.000 {method '__exit__' of 'numpy.nditer' objects}
#        10    0.000    0.000    0.000    0.000 managers.py:2194(_stack_arrays)
#        60    0.000    0.000    0.000    0.000 module.py:2322(named_children)
#         1    0.000    0.000    0.001    0.001 {built-in method _warnings.warn}
#         1    0.000    0.000    0.013    0.013 _filters.py:326(gaussian_filter)
#       305    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 common.py:289(_get_filepath_or_buffer)
#        12    0.000    0.000    0.000    0.000 concat.py:389(is_na)
#        16    0.000    0.000    0.000    0.000 _base.py:244(_asfptype)
#         4    0.000    0.000    0.000    0.000 {method 'view' of 'torch._C.TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'random_' of 'torch._C.TensorBase' objects}
#         2    0.000    0.000    0.002    0.001 concat.py:618(get_result)
#       345    0.000    0.000    0.000    0.000 traitlets.py:222(__call__)
#         7    0.000    0.000    0.000    0.000 inspect.py:2920(__init__)
#        34    0.000    0.000    0.000    0.000 _methods.py:61(_all)
#        17    0.000    0.000    0.000    0.000 fromnumeric.py:2322(any)
#       4/3    0.000    0.000    0.042    0.014 common.py:515(_run_forward)
#        14    0.000    0.000    0.000    0.000 session.py:673(sign)
#       117    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 format.py:564(__init__)
#         1    0.000    0.000    0.004    0.004 dataset.py:419(<listcomp>)
#       101    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#         2    0.000    0.000    0.000    0.000 dataloader.py:565(__init__)
#        96    0.000    0.000    0.000    0.000 _base.py:361(format)
#         1    0.000    0.000    0.010    0.010 notebook.py:202(__init__)
#         3    0.000    0.000    0.004    0.001 format.py:1103(to_csv)
#         3    0.000    0.000    0.001    0.000 csvs.py:301(_save_body)
#        14    0.000    0.000    0.000    0.000 session.py:647(msg)
#         8    0.000    0.000    0.000    0.000 common.py:1155(_is_binary_mode)
#        21    0.000    0.000    0.001    0.000 traitlets.py:721(set)
#         3    0.000    0.000    0.004    0.001 csvs.py:242(save)
#        22    0.000    0.000    0.000    0.000 threading.py:1169(is_alive)
#        61    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#        28    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#        86    0.000    0.000    0.000    0.000 ElementTree.py:1641(_start)
#         8    0.000    0.000    0.001    0.000 _tensor.py:34(wrapped)
#         1    0.000    0.000    0.017    0.017 deep_lift.py:368(forward_fn)
#         9    0.000    0.000    0.000    0.000 inspect.py:2637(__init__)
#         2    0.000    0.000    0.001    0.001 ImageFile.py:186(load)
#       345    0.000    0.000    0.000    0.000 traitlets.py:219(__init__)
#      11/4    0.000    0.000    0.005    0.001 widget.py:500(__init__)
#         1    0.000    0.000    0.000    0.000 util.py:9(cut_model_from_layer)
#         8    0.000    0.000    0.000    0.000 cast.py:1544(construct_1d_object_array_from_listlike)
#        20    0.000    0.000    0.000    0.000 config.py:633(_get_root)
#       306    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#       128    0.000    0.000    0.000    0.000 stride_tricks.py:363(_broadcast_to_dispatcher)
#        48    0.000    0.000    0.000    0.000 construction.py:673(_sanitize_ndim)
#         2    0.000    0.000    0.000    0.000 deep_lift.py:391(_forward_pre_hook)
#      22/1    0.000    0.000    0.000    0.000 module.py:2411(train)
#         8    0.000    0.000    0.000    0.000 _tensor.py:964(__rsub__)
#         7    0.000    0.000    0.000    0.000 {pandas._libs.lib.array_equivalent_object}
#       404    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         2    0.000    0.000    4.433    2.217 road.py:173(__call__)
#        10    0.000    0.000    0.000    0.000 _asarray.py:27(require)
#         1    0.000    0.000    0.403    0.403 attributions.py:141(attribute)
#        11    0.000    0.000    0.000    0.000 traitlets.py:1314(setup_instance)
#        14    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#        37    0.000    0.000    0.000    0.000 construction.py:484(ensure_wrapped_if_datetimelike)
#         3    0.000    0.000    0.000    0.000 container.py:99(__init__)
#        32    0.000    0.000    0.000    0.000 _compressed.py:1259(has_sorted_indices)
#       129    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#        20    0.000    0.000    0.000    0.000 config.py:145(_get_option)
#       144    0.000    0.000    0.000    0.000 _sputils.py:462(<genexpr>)
#         2    0.000    0.000    0.000    0.000 concat.py:296(_get_combined_plan)
#         2    0.000    0.000    0.093    0.046 graph.py:739(_engine_run_backward)
#        58    0.000    0.000    0.000    0.000 construction.py:419(extract_array)
#        10    0.000    0.000    0.000    0.000 hooks.py:34(remove)
#        27    0.000    0.000    0.000    0.000 managers.py:1005(iget_values)
#         1    0.000    0.000    0.000    0.000 {built-in method torch.chunk}
#        11    0.000    0.000    0.000    0.000 traitlets.py:1356(__init__)
#         6    0.000    0.000    0.000    0.000 common.py:1587(pandas_dtype)
#        60    0.000    0.000    0.000    0.000 module.py:2313(children)
#        16    0.000    0.000    0.000    0.000 {built-in method torch.ones_like}
#         3    0.000    0.000    0.000    0.000 util.py:198(get_layer_name)
#        74    0.000    0.000    0.000    0.000 base.py:908(__len__)
#        16    0.000    0.000    0.000    0.000 _sputils.py:25(upcast)
#         4    0.000    0.000    0.000    0.000 common.py:538(infer_compression)
#        11    0.000    0.000    0.000    0.000 inspect.py:2840(apply_defaults)
#         3    0.000    0.000    0.000    0.000 {method 'encode' of 'ImagingEncoder' objects}
#         5    0.000    0.000    0.000    0.000 _ni_support.py:78(_get_output)
#        23    0.000    0.000    0.000    0.000 common.py:1425(_is_dtype_type)
#        14    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#         2    0.000    0.000    0.000    0.000 astype.py:56(_astype_nansafe)
#        86    0.000    0.000    0.000    0.000 ElementTree.py:1653(_end)
#        18    0.000    0.000    0.000    0.000 construction.py:1028(convert)
#        16    0.000    0.000    0.000    0.000 {method 'add_index_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#        11    0.000    0.000    0.000    0.000 traitlets.py:1342(setup_instance)
#         3    0.000    0.000    0.000    0.000 csvs.py:57(__init__)
#         9    0.000    0.000    0.000    0.000 indexing.py:2442(__setitem__)
#        82    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        11    0.000    0.000    0.000    0.000 inspect.py:2787(args)
#        83    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        11    0.000    0.000    0.002    0.000 base_comm.py:69(open)
#         3    0.000    0.000    0.001    0.000 iostream.py:626(write)
#         1    0.000    0.000    0.000    0.000 __init__.py:48(create_string_buffer)
#         1    0.000    0.000    0.005    0.005 notebook.py:94(status_printer)
#        13    0.000    0.000    0.000    0.000 kernelbase.py:620(get_parent)
#         1    0.000    0.000    0.000    0.000 JpegImagePlugin.py:339(_open)
#        14    0.000    0.000    0.000    0.000 session.py:598(msg_id)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:355(_concatenate_chunks)
#         2    0.000    0.000    0.000    0.000 {built-in method torch.as_tensor}
#         1    0.000    0.000    0.000    0.000 std.py:952(__init__)
#         2    0.000    0.000    0.000    0.000 concat.py:403(__init__)
#        22    0.000    0.000    0.000    0.000 threading.py:1102(_wait_for_tstate_lock)
#        56    0.000    0.000    0.000    0.000 encoder.py:104(__init__)
#        34    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        11    0.000    0.000    0.000    0.000 traitlets.py:1299(__new__)
#        14    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#        16    0.000    0.000    0.000    0.000 _compressed.py:1222(has_canonical_format)
#         1    0.000    0.000    0.001    0.001 formatters.py:90(format)
#         9    0.000    0.000    0.000    0.000 csvs.py:175(_number_format)
#        17    0.000    0.000    0.000    0.000 traitlets.py:3446(validate)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:3385(mean)
#         4    0.000    0.000    0.000    0.000 parse.py:371(urlparse)
#       172    0.000    0.000    0.000    0.000 ElementTree.py:1624(_fixname)
#         3    0.000    0.000    0.000    0.000 _dtype.py:346(_name_get)
#         1    0.000    0.000    0.000    0.000 utils.py:297(_screen_shape_windows)
#        25    0.000    0.000    0.000    0.000 blocks.py:2346(get_block_type)
#        17    0.000    0.000    0.000    0.000 traitlets.py:759(_cross_validate)
#        14    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#        14    0.000    0.000    0.000    0.000 session.py:279(extract_header)
#         2    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#        19    0.000    0.000    0.000    0.000 generic.py:6206(__setattr__)
#        96    0.000    0.000    0.000    0.000 multiarray.py:503(can_cast)
#        11    0.000    0.000    0.000    0.000 base.py:69(shape)
#         1    0.000    0.000    0.000    0.000 warnings.py:35(_formatwarnmsg_impl)
#         9    0.000    0.000    0.000    0.000 blocks.py:247(make_block)
#        56    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        18    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        75    0.000    0.000    0.000    0.000 range.py:963(__len__)
#       9/1    0.000    0.000    0.000    0.000 module.py:857(apply)
#     52/17    0.000    0.000    0.004    0.000 traitlets.py:586(default)
#         3    0.000    0.000    0.000    0.000 pathlib.py:56(parse_parts)
#         4    0.000    0.000    0.000    0.000 cast.py:1400(find_common_type)
#         6    0.000    0.000    0.000    0.000 range.py:198(_simple_new)
#         2    0.000    0.000    0.000    0.000 construction.py:928(_finalize_columns_and_data)
#         1    0.000    0.000    0.000    0.000 {built-in method torch.zeros_like}
#         1    0.000    0.000    0.000    0.000 {built-in method torch.unbind}
#        40    0.000    0.000    0.000    0.000 config.py:647(_get_deprecated_option)
#         7    0.000    0.000    0.000    0.000 inspect.py:612(unwrap)
#         1    0.000    0.000    0.009    0.009 readers.py:848(read_csv)
#        19    0.000    0.000    0.000    0.000 blocks.py:2467(extend_blocks)
#        11    0.000    0.000    0.000    0.000 uuid.py:718(uuid4)
#        15    0.000    0.000    0.001    0.000 traitlets.py:1531(_notify_trait)
#       273    0.000    0.000    0.000    0.000 widget.py:792(_trait_to_json)
#         2    0.000    0.000    0.000    0.000 _tensor.py:1021(__len__)
#         9    0.000    0.000    0.000    0.000 deep_lift.py:460(_can_register_hook)
#        16    0.000    0.000    0.002    0.000 _compressed.py:1228(sum_duplicates)
#        64    0.000    0.000    0.000    0.000 _csc.py:145(_swap)
#        11    0.000    0.000    0.000    0.000 widget.py:537(_comm_changed)
#        13    0.000    0.000    0.000    0.000 blocks.py:2388(new_block)
#         3    0.000    0.000    0.000    0.000 inspect.py:1959(_signature_bound_method)
#         1    0.000    0.000    0.072    0.072 __init__.py:165(backward)
#         1    0.000    0.000    0.000    0.000 functional.py:378(resize)
#         4    0.000    0.000    0.000    0.000 managers.py:2068(create_block_manager_from_column_arrays)
#        12    0.000    0.000    0.000    0.000 ntpath.py:315(expanduser)
#         4    0.000    0.000    0.000    0.000 parse.py:436(urlsplit)
#         3    0.000    0.000    0.000    0.000 generic.py:4296(_slice)
#        20    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#         7    0.000    0.000    0.000    0.000 cast.py:119(maybe_convert_platform)
#         3    0.000    0.000    0.000    0.000 managers.py:1740(<listcomp>)
#         1    0.000    0.000    0.021    0.021 __init__.py:278(grad)
#        14    0.000    0.000    0.001    0.000 iostream.py:343(send_multipart)
#         9    0.000    0.000    0.000    0.000 {built-in method torch._C._log_api_usage_once}
#         9    0.000    0.000    0.000    0.000 blocks.py:633(to_native_types)
#         1    0.000    0.000    0.002    0.002 voc.py:192(__getitem__)
#        14    0.000    0.000    0.000    0.000 session.py:643(msg_header)
#         4    0.000    0.000    0.000    0.000 module.py:1770(__delattr__)
#        56    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 deep_lift.py:814(_expand_inputs_baselines_targets)
#         3    0.000    0.000    0.000    0.000 csvs.py:229(encoded_labels)
#        50    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 base_parser.py:114(__init__)
#        14    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#        12    0.000    0.000    0.000    0.000 concat.py:322(_get_block_for_concat_plan)
#         1    0.000    0.000    0.001    0.001 notebook.py:139(display)
#        32    0.000    0.000    0.000    0.000 _sputils.py:551(convert_pydata_sparse_to_scipy)
#         2    0.000    0.000    0.001    0.000 concat.py:698(<listcomp>)
#         6    0.000    0.000    0.000    0.000 contextlib.py:102(__init__)
#         2    0.000    0.000    0.001    0.001 deep_lift.py:416(_backward_hook)
#        17    0.000    0.000    0.000    0.000 arraysetops.py:125(_unpack_tuple)
#        20    0.000    0.000    0.000    0.000 config.py:271(__call__)
#         1    0.000    0.000    0.000    0.000 {built-in method torch._ops.profiler.}
#        13    0.000    0.000    0.000    0.000 typing.py:306(inner)
#        16    0.000    0.000    0.000    0.000 road.py:50(__init__)
#         4    0.000    0.000    0.000    0.000 cast.py:1359(np_find_common_type)
#        12    0.000    0.000    0.000    0.000 concat.py:597(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'bytes' objects}
#         1    0.000    0.000    0.009    0.009 readers.py:574(_read)
#         7    0.000    0.000    0.000    0.000 missing.py:466(array_equivalent)
#        48    0.000    0.000    0.000    0.000 construction.py:712(_sanitize_str_dtypes)
#         1    0.000    0.000    0.000    0.000 re.py:222(split)
#        56    0.000    0.000    0.000    0.000 hmac.py:117(update)
#        83    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#        11    0.000    0.000    0.001    0.000 widget.py:488(_default_keys)
#         8    0.000    0.000    0.000    0.000 missing.py:305(_isna_string_dtype)
#         2    0.000    0.000    0.000    0.000 {method 'squeeze' of 'torch._C.TensorBase' objects}
#        39    0.000    0.000    0.000    0.000 common.py:556(require_length_match)
#        42    0.000    0.000    0.000    0.000 _jit_internal.py:1120(is_scripting)
#        14    0.000    0.000    0.000    0.000 common.py:137(is_object_dtype)
#        64    0.000    0.000    0.000    0.000 _data.py:24(dtype)
#         1    0.000    0.000    0.010    0.010 results_metrics.py:28(load_results)
#         2    0.000    0.000    0.000    0.000 base.py:1682(_validate_names)
#         1    0.000    0.000    0.000    0.000 deep_lift.py:825(<listcomp>)
#        86    0.000    0.000    0.000    0.000 {method 'start' of 'xml.etree.ElementTree.TreeBuilder' objects}
#         3    0.000    0.000    0.000    0.000 common.py:26(_sum_rows)
#         1    0.000    0.000    0.000    0.000 range.py:902(_concat)
#         4    0.000    0.000    0.000    0.000 managers.py:1825(from_array)
#         4    0.000    0.000    0.000    0.000 common.py:145(is_url)
#         3    0.000    0.000    0.000    0.000 {method 'writerow' of '_csv.writer' objects}
#         2    0.000    0.000    0.000    0.000 std.py:400(format_interval)
#       3/1    0.000    0.000    0.000    0.000 collate.py:108(collate)
#         9    0.000    0.000    0.000    0.000 indexing.py:2431(__getitem__)
#        11    0.000    0.000    0.000    0.000 inspect.py:2810(kwargs)
#        19    0.000    0.000    0.000    0.000 managers.py:1960(internal_values)
#         1    0.000    0.000    0.007    0.007 readers.py:1673(_make_engine)
#        12    0.000    0.000    0.000    0.000 formatters.py:373(lookup)
#        11    0.000    0.000    0.002    0.000 ipkernel.py:46(_create_comm)
#         9    0.000    0.000    0.000    0.000 deep_lift.py:470(_register_hooks)
#        42    0.000    0.000    0.000    0.000 __init__.py:43(using_pyarrow_string_dtype)
#        48    0.000    0.000    0.000    0.000 construction.py:732(_maybe_repeat)
#        14    0.000    0.000    0.000    0.000 session.py:852(<listcomp>)
#         3    0.000    0.000    0.000    0.000 common.py:593(check_parent_directory)
#         9    0.000    0.000    0.000    0.000 formatters.py:330(__call__)
#        11    0.000    0.000    0.002    0.000 comm.py:27(create_comm)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_concat_blkno_indexers}
#       2/1    0.000    0.000    0.064    0.064 __init__.py:40(wrapper)
#        69    0.000    0.000    0.000    0.000 traitlets.py:1835(has_trait)
#         1    0.000    0.000    0.004    0.004 display_functions.py:105(display)
#         8    0.000    0.000    0.000    0.000 _ufunc_config.py:452(_no_nep50_warning)
#        25    0.000    0.000    0.000    0.000 missing.py:101(isna)
#         1    0.000    0.000    0.001    0.001 transforms.py:93(__call__)
#         1    0.000    0.000    0.000    0.000 functional.py:327(normalize)
#         4    0.000    0.000    0.001    0.000 construction.py:96(arrays_to_mgr)
#         8    0.000    0.000    0.000    0.000 common.py:233(stringify_path)
#         9    0.000    0.000    0.000    0.000 series.py:1316(_set_values)
#         2    0.000    0.000    0.000    0.000 series.py:6131(any)
#         7    0.000    0.000    0.004    0.001 trait_types.py:408(make_dynamic_default)
#         1    0.000    0.000    0.000    0.000 Image.py:3482(_open_core)
#        16    0.000    0.000    0.000    0.000 base.py:7607(maybe_extract_name)
#         2    0.000    0.000    0.000    0.000 collate.py:194(collate_tensor_fn)
#         2    0.000    0.000    0.000    0.000 api.py:202(union_indexes)
#         1    0.000    0.000    0.004    0.004 dataloader.py:626(__next__)
#         1    0.000    0.000    0.000    0.000 Image.py:3409(open)
#        40    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#       5/1    0.000    0.000    0.000    0.000 symbolic_shapes.py:425(sym_eq)
#         5    0.000    0.000    0.000    0.000 module.py:1378(register_forward_pre_hook)
#        16    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.001    0.001 c_parser_wrapper.py:222(read)
#        32    0.000    0.000    0.000    0.000 traitlets.py:2314(validate)
#         3    0.000    0.000    0.000    0.000 indexing.py:1139(__getitem__)
#         3    0.000    0.000    0.000    0.000 indexing.py:1718(_get_slice_axis)
#        12    0.000    0.000    0.000    0.000 common.py:173(_expand_user)
#        36    0.000    0.000    0.000    0.000 managers.py:2124(_grouping_func)
#        14    0.000    0.000    0.001    0.000 traitlets.py:1257(__call__)
#        10    0.000    0.000    0.000    0.000 cast.py:1483(construct_1d_arraylike_from_scalar)
#        11    0.000    0.000    0.001    0.000 decorator.py:229(fun)
#         2    0.000    0.000    0.002    0.001 iostream.py:563(flush)
#        18    0.000    0.000    0.000    0.000 voc.py:219(<dictcomp>)
#        18    0.000    0.000    0.000    0.000 common.py:1322(is_ea_or_datetimelike_dtype)
# ...
#         9    0.000    0.000    0.000    0.000 csvs.py:103(float_format)
#         6    0.000    0.000    0.000    0.000 csvs.py:115(index)
#         3    0.000    0.000    0.000    0.000 csvs.py:141(_initialize_quotechar)
#         1    0.000    0.000    0.000    0.000 sampler.py:110(__iter__)
#         1    0.000    0.000    0.000    0.000 notebook.py:71(_json_)
#        15    0.000    0.000    0.000    0.000 Image.py:579(size)
#         2    0.000    0.000    0.000    0.000 road.py:162(__init__)
#         2    0.000    0.000    0.000    0.000 managers.py:536(nblocks)
#         3    0.000    0.000    0.000    0.000 inspect.py:404(isbuiltin)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:3424(compare)
#         1    0.000    0.000    0.001    0.001 widget_box.py:62(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method torch.get_default_dtype}
#        11    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 utils.py:108(__init__)
#         1    0.000    0.000    0.000    0.000 _functional_pil.py:41(get_image_num_channels)
#         6    0.000    0.000    0.000    0.000 cast.py:1446(<genexpr>)
#         3    0.000    0.000    0.000    0.000 format.py:670(_initialize_formatters)
#         2    0.000    0.000    0.000    0.000 JpegImagePlugin.py:408(load_read)
#         2    0.000    0.000    0.000    0.000 threading.py:264(__enter__)
#         8    0.000    0.000    0.000    0.000 parse.py:103(_noop)
#         1    0.000    0.000    0.000    0.000 widget_float.py:33(_validate_value)
#         3    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         3    0.000    0.000    0.000    0.000 common.py:235(_format_inputs)
#         5    0.000    0.000    0.000    0.000 common.py:273(_format_additional_forward_args)
#         1    0.000    0.000    0.000    0.000 attribution.py:290(<listcomp>)
#         1    0.000    0.000    0.000    0.000 symbolic_shapes.py:655(expect_true)
#         2    0.000    0.000    0.000    0.000 common.py:91(ensure_python_int)
#         6    0.000    0.000    0.000    0.000 common.py:175(<genexpr>)
#         1    0.000    0.000    0.000    0.000 series.py:581(_constructor_from_mgr)
#         1    0.000    0.000    0.000    0.000 readers.py:1502(_check_file_or_buffer)
#         1    0.000    0.000    0.000    0.000 types.py:176(__get__)
#         2    0.000    0.000    0.000    0.000 threading.py:273(_release_save)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3973(validate_elements)
#         1    0.000    0.000    0.000    0.000 zmqshell.py:73(_hooks)
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._are_functorch_transforms_active}
#         2    0.000    0.000    0.000    0.000 distributed_c10d.py:460(default_pg)
#         3    0.000    0.000    0.000    0.000 std.py:226(__init__)
#         1    0.000    0.000    0.000    0.000 ImageFile.py:260(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _functional_tensor.py:13(_assert_image_tensor)
#         2    0.000    0.000    0.000    0.000 concat.py:148(<setcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:1899(rename)
#         4    0.000    0.000    0.000    0.000 concat.py:357(_is_valid_na_for)
#         2    0.000    0.000    0.000    0.000 concat.py:536(<listcomp>)
#         2    0.000    0.000    0.000    0.000 concat.py:689(_get_result_dim)
#         4    0.000    0.000    0.000    0.000 common.py:1219(<genexpr>)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:1229(user_global_ns)
#         7    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#         4    0.000    0.000    0.000    0.000 utils.py:222(__eq__)
#         5    0.000    0.000    0.000    0.000 dataloader.py:441(_auto_collation)
#         1    0.000    0.000    0.000    0.000 functional.py:117(_is_numpy)
#         3    0.000    0.000    0.000    0.000 common.py:126(_classes_and_not_datetimelike)
#         4    0.000    0.000    0.000    0.000 cast.py:1439(<genexpr>)
#         2    0.000    0.000    0.000    0.000 common.py:171(not_none)
#         9    0.000    0.000    0.000    0.000 base.py:363(ndim)
#         1    0.000    0.000    0.000    0.000 range.py:946(<listcomp>)
#         1    0.000    0.000    0.000    0.000 blocks.py:2586(external_values)
#         7    0.000    0.000    0.000    0.000 series.py:1381(_clear_item_cache)
#         1    0.000    0.000    0.000    0.000 displaypub.py:43(_validate_data)
#         1    0.000    0.000    0.000    0.000 widget.py:52(<listcomp>)
#         2    0.000    0.000    0.000    0.000 common.py:78(_is_tuple)
#         1    0.000    0.000    0.000    0.000 deep_lift.py:361(_construct_forward_func)
#         1    0.000    0.000    0.000    0.000 PngImagePlugin.py:742(_accept)
#         1    0.000    0.000    0.000    0.000 voc.py:188(annotations)
#         2    0.000    0.000    0.000    0.000 concat.py:149(<setcomp>)
#         1    0.000    0.000    0.000    0.000 common.py:185(all_none)
#         1    0.000    0.000    0.000    0.000 blocks.py:222(external_values)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1247(_process_date_conversion)
#         2    0.000    0.000    0.000    0.000 JpegImagePlugin.py:395(__getattr__)
#         1    0.000    0.000    0.000    0.000 JpegImagePlugin.py:527(_getmp)
#         1    0.000    0.000    0.000    0.000 JpegImagePlugin.py:537(_getmp)
#         4    0.000    0.000    0.000    0.000 threading.py:1145(ident)
#         1    0.000    0.000    0.000    0.000 widget_float.py:51(_validate_max)
#         1    0.000    0.000    0.000    0.000 {method 'setimage' of 'ImagingDecoder' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISDIR}
#         1    0.000    0.000    0.000    0.000 _monitor.py:94(report)
#         1    0.000    0.000    0.000    0.000 std.py:1157(__hash__)
#         1    0.000    0.000    0.000    0.000 ElementTree.py:1656(_default)
#         2    0.000    0.000    0.000    0.000 function.py:64(__call__)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:212(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:278(_extract_multi_indexer_columns)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:392(ensure_dtype_objs)
#         2    0.000    0.000    0.000    0.000 JpegImagePlugin.py:326(_accept)
#         9    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 std.py:682(<setcomp>)
#         1    0.000    0.000    0.000    0.000 Image.py:344(preinit)
#         4    0.000    0.000    0.000    0.000 range.py:377(dtype)
#         1    0.000    0.000    0.000    0.000 range.py:973(__getitem__)
#         1    0.000    0.000    0.000    0.000 readers.py:1782(__exit__)
#         3    0.000    0.000    0.000    0.000 base_parser.py:1425(is_index_col)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:330(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2948(validate)
#         1    0.000    0.000    0.000    0.000 {built-in method PIL._imaging.raw_encoder}
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 std.py:113(__exit__)
#         1    0.000    0.000    0.000    0.000 sampler.py:113(__len__)
#         1    0.000    0.000    0.000    0.000 functional.py:353(_compute_resized_output_size)
#         4    0.000    0.000    0.000    0.000 cast.py:1441(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:5461(<listcomp>)
#         2    0.000    0.000    0.000    0.000 base.py:5634(<genexpr>)
#         3    0.000    0.000    0.000    0.000 range.py:911(<genexpr>)
#         1    0.000    0.000    0.000    0.000 series.py:708(values)
#         2    0.000    0.000    0.000    0.000 series.py:821(__len__)
#         1    0.000    0.000    0.000    0.000 readers.py:1850(_clean_na_values)
#         1    0.000    0.000    0.000    0.000 readers.py:2153(_validate_skipfooter)
#         1    0.000    0.000    0.000    0.000 GifImagePlugin.py:69(_accept)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:315(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 enum.py:783(__hash__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:21(__enter__)
#         1    0.000    0.000    0.000    0.000 {method 'is_floating_point' of 'torch._C.TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 __init__.py:360(<genexpr>)
#         3    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#         3    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         1    0.000    0.000    0.000    0.000 utils.py:252(_is_utf)
#         1    0.000    0.000    0.000    0.000 attributions.py:29(__init__)
#         1    0.000    0.000    0.000    0.000 attribution.py:31(__init__)
#         2    0.000    0.000    0.000    0.000 concat.py:766(_maybe_check_integrity)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:213(<listcomp>)
#         1    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         3    0.000    0.000    0.000    0.000 codecs.py:331(getstate)
#         2    0.000    0.000    0.000    0.000 threading.py:279(_is_owned)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:17(__init__)
#         1    0.000    0.000    0.000    0.000 widget_float.py:41(_validate_min)
#         4    0.000    0.000    0.000    0.000 multiarray.py:669(result_type)
#         1    0.000    0.000    0.000    0.000 module.py:1712(remove_from)
#         1    0.000    0.000    0.000    0.000 module.py:2433(eval)
#         1    0.000    0.000    0.000    0.000 grad_mode.py:192(__enter__)
#         1    0.000    0.000    0.000    0.000 {method 'setimage' of 'ImagingEncoder' objects}
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 deep_lift.py:534(multiplies_by_inputs)
#         4    0.000    0.000    0.000    0.000 Image.py:567(im)
#         1    0.000    0.000    0.000    0.000 ElementTree.py:536(__init__)
#         1    0.000    0.000    0.000    0.000 _validators.py:450(check_dtype_backend)
#         4    0.000    0.000    0.000    0.000 range.py:299(stop)
#         4    0.000    0.000    0.000    0.000 range.py:316(step)
#         3    0.000    0.000    0.000    0.000 format.py:637(is_truncated_vertically)
#         3    0.000    0.000    0.000    0.000 format.py:751(_adjust_max_rows)
#         3    0.000    0.000    0.000    0.000 common.py:138(__enter__)
#         1    0.000    0.000    0.000    0.000 base_parser.py:349(_maybe_make_multi_index_columns)
#         1    0.000    0.000    0.000    0.000 base_parser.py:883(_check_data_length)
#         1    0.000    0.000    0.000    0.000 base_parser.py:976(_validate_usecols_arg)
#         1    0.000    0.000    0.000    0.000 BmpImagePlugin.py:52(_accept)
#         1    0.000    0.000    0.000    0.000 JpegImagePlugin.py:498(_read_dpi_from_exif)
#         1    0.000    0.000    0.000    0.000 enum.py:801(value)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         3    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         3    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 std.py:760(get_lock)
#         1    0.000    0.000    0.000    0.000 utils.py:139(__getattr__)
#         2    0.000    0.000    0.000    0.000 worker.py:89(get_worker_info)
#         1    0.000    0.000    0.000    0.000 dataloader.py:620(_next_index)
#         2    0.000    0.000    0.000    0.000 Image.py:571(width)
#         2    0.000    0.000    0.000    0.000 base.py:538(<genexpr>)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:326(<listcomp>)
#         1    0.000    0.000    0.000    0.000 container.py:139(__len__)
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 std.py:167(colour)
#         1    0.000    0.000    0.000    0.000 range.py:922(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:254(_has_complex_date_col)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencoding}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 utils.py:282(_screen_shape_wrapper)
#         1    0.000    0.000    0.000    0.000 collate.py:168(<genexpr>)
#         2    0.000    0.000    0.000    0.000 Image.py:575(height)
#         1    0.000    0.000    0.000    0.000 missing.py:971(clean_reindex_fill_method)
#         1    0.000    0.000    0.000    0.000 range.py:213(_validate_dtype)
#         2    0.000    0.000    0.000    0.000 series.py:577(_constructor)
#         2    0.000    0.000    0.000    0.000 readers.py:518(validate_integer)
#         1    0.000    0.000    0.000    0.000 readers.py:2055(_extract_dialect)
#         1    0.000    0.000    0.000    0.000 copy.py:107(_copy_immutable)
#         1    0.000    0.000    0.000    0.000 multiarray.py:346(where)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:127(annotate)
#         1    0.000    0.000    0.000    0.000 utils.py:112(__format__)
#         1    0.000    0.000    0.000    0.000 ImageFile.py:263(<lambda>)
#         1    0.000    0.000    0.000    0.000 common.py:671(<lambda>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:234(<setcomp>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:246(<listcomp>)
#         1    0.000    0.000    0.000    0.000 jsonutil.py:52(encode_images)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of 'torch._C.DisableTorchFunctionSubclass' objects}
#         2    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x0000013AC2FF15A0}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 std.py:163(colour)
#         1    0.000    0.000    0.000    0.000 ImageFile.py:93(_tilesort)
#         1    0.000    0.000    0.000    0.000 ImageFile.py:331(load_end)
#         2    0.000    0.000    0.000    0.000 common.py:189(<genexpr>)
#         1    0.000    0.000    0.000    0.000 readers.py:550(_validate_names)
#         2    0.000    0.000    0.000    0.000 traitlets.py:1366(ignore)
#         1    0.000    0.000    0.000    0.000 formatters.py:830(_check_return)
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 ElementTree.py:542(getroot)
#         1    0.000    0.000    0.000    0.000 range.py:228(_constructor)
#         1    0.000    0.000    0.000    0.000 managers.py:1790(ndim)
#         1    0.000    0.000    0.000    0.000 readers.py:1779(__enter__)
#         1    0.000    0.000    0.000    0.000 {method 'cleanup' of 'ImagingDecoder' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of 'xml.etree.ElementTree.TreeBuilder' objects}
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.audit}
